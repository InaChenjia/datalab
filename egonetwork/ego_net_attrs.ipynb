# %%
try:
    import cPickle as pickle
except ImportError:
    import pickle

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
info = 'call'
samples = map(lambda x: x.strip('\r\n'), open('/home/sysadmin/zhicongchen/mobile-network-analysis/egonetwork/samples/' + info + '_samples.txt', 'r').readlines())
sample1 = samples[:100]
print sample1
# Out:
# ['942920', '275619', '1252872', '133320', '572076', '1291830', '1086685', '242842', '1209948', '733107', '1288488', '130895', '448086', '518198', '1206481', '906376', '653841', '37253', '1335933', '449402', '423315', '633153', '476446', '140647', '825114', '195102', '727357', '946296', '853117', '339516', '263317', '1295295', '274393', '52247', '1318617', '1175648', '30133', '791830', '302736', '162771', '619794', '1330160', '151019', '995844', '442011', '138815', '753845', '645752', '1007383', '94169', '344124', '640239', '1007850', '363088', '60557', '1094064', '371708', '148449', '721087', '1043967', '560091', '1145500', '660187', '1166655', '893942', '718895', '239809', '286929', '59902', '280020', '1320935', '315629', '403570', '910750', '904142', '1030091', '658062', '713103', '1228924', '1124927', '983813', '1205989', '337109', '396633', '250985', '21652', '1146035', '867130', '597', '368116', '1329616', '997853', '576798', '333342', '578152', '620513', '258784', '339170', '11
# ...

# %%
eg3_sizes = map(lambda x: int(x.strip('\r\n').split(': ')[-1]), open('/home/sysadmin/zhicongchen/data/phone_data/logs/call_eg3size.log', 'r').readlines())
print eg3_sizes[:100]
# Out:
# [490134, 316, 3461147, 849, 18710, 3966, 3103, 2841964, 137580, 70172, 2483, 3288194, 621892, 5870, 429500, 3040298, 2242, 155352, 137386, 929719, 2552682, 772, 150416, 1644090, 3805476, 13521, 217630, 160222, 1695201, 1957564, 1634258, 152124, 2060608, 66966, 48336, 3622093, 1932889, 2764630, 1542483, 1542587, 3395897, 3449861, 3471422, 462863, 2791764, 2763115, 576738, 21648, 1001, 255262, 195801, 1757363, 219034, 771, 63476, 3402291, 69988, 181754, 5900, 691, 800673, 1008, 2764041, 2763410, 2790071, 146472, 75507, 156430, 2757188, 356985, 149486, 2231, 401, 1597, 462705, 2897582, 84832, 2756056, 1263, 356328, 177785, 199890, 1254, 1016440, 160892, 129039, 646, 2756133, 1023024, 182452, 233259, 4682, 152960, 18471, 3404343, 442815, 1689300, 2758137, 2175, 159477]

# %%
dump_file = '/home/sysadmin/zhicongchen/data/phone_data/dumps/call_eg_dump/call_' + samples[0] + '_eg3_dump.txt'
f = open(dump_file, 'rb')
eg3 = pickle.load(f)
f.close()
print len(eg3.nodes())
# Out:
# 490134

# %%
dump_file = '/home/sysadmin/zhicongchen/data/phone_data/dumps/call_eg_dump/call_' + samples[0] + '_eg2_dump.txt'
f = open(dump_file, 'rb')
eg2 = pickle.load(f)
f.close()
print len(eg2.nodes())
# Out:
# 9460

# %%
plt.figure(figsize=(8,8))
pos=nx.spring_layout(eg2)
nx.draw_networkx_nodes(eg2,pos,node_size=12,node_color='b')
nx.draw_networkx_edges(eg2,pos,edge_color='#8F8F8F') 
#nx.draw_networkx_labels(eg3,pos,fontsize=5)
plt.show()

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.assortativity.degree_assortativity_coefficient.html#networkx.algorithms.assortativity.degree_assortativity_coefficient
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.assortativity.degree_pearson_correlation_coefficient.html#networkx.algorithms.assortativity.degree_pearson_correlation_coefficient
def cal_assortativity(G):

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.cluster.clustering.html
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.cluster.average_clustering.html
def cal_clustering(G):

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.approximation.connectivity.all_pairs_node_connectivity.html#networkx.algorithms.approximation.connectivity.all_pairs_node_connectivity
def cal_connectivity(G):

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.cluster.triangles.html

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.cluster.transitivity.html

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.centrality.degree_centrality.html#networkx.algorithms.centrality.degree_centrality
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.centrality.in_degree_centrality.html#networkx.algorithms.centrality.in_degree_centrality
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.centrality.out_degree_centrality.html#networkx.algorithms.centrality.out_degree_centrality

# %%
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.centrality.degree_centrality.html#networkx.algorithms.centrality.degree_centrality
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.centrality.closeness_centrality.html#networkx.algorithms.centrality.closeness_centrality
# http://networkx.readthedocs.org/en/networkx-1.11/reference/generated/networkx.algorithms.centrality.betweenness_centrality.html#networkx.algorithms.centrality.betweenness_centrality
def cal_closeness(G):
    print [nx.closeness_centrality(eg2, eg2.nodes()[i]) for i in range(len(eg2.nodes()))]
